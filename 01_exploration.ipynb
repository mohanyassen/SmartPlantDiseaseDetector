# %% [markdown]
# # Tomato Disease Detector — Exploration Notebook
#
# Load data, preview samples, prepare for YOLO training.

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os, cv2, matplotlib.pyplot as plt

# %%
print('Load and preview images here...')
